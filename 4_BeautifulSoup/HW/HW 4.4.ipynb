# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ##### Задача
#  найти тег который имеет имя и значение атрибута data-gpu="nVidia GeForce RTX 4060"

# %%
html_str = '<div name_attr="value attr">Информация в теге</div>'

# %%
soup = BeautifulSoup(html_str, 'html.parser')

# %%
soup.find(attrs={'name_attr': 'value attr'})
# Out:
# <div name_attr="value attr">Информация в теге</div>

# %%
soup.find(attrs={"data-gpu": "nVidia GeForce RTX 4060"})

# %% [markdown]
# Найдите тег \<li> который имеет имя атрибута data-key и значение атрибута cooling_system

# %%
li_tag = soup.find('li', {'data-key': 'cooling_system'})

# %% [markdown]
# ##### Задача
# Ваша задача, проанализировать страницу и понять как извлечь тег \<img> целиком.
# https://parsinger.ru/4.1/1/index.html

# %%
url = 'https://parsinger.ru/4.1/1/index.html'

# %%
r = requests.get(url)
if r.status_code != 200:
    print(r.status_code, '\n\n', r.text)

# %%
r.encoding = 'utf-8'

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
img = soup.find('img', attrs={'src': 'images/Видеокарта MSI Radeon RX 6650 XT MECH 2X OC PCI-E 8192Mb GDDR6 128 Bit '
                                   'Retail.jpg'})

# %%
print(img)
# Out:
# <img alt="Видеокарта MSI Radeon RX 6650 XT MECH 2X OC PCI-E 8192Mb GDDR6 128 Bit Retail" src="images/Видеокарта MSI Radeon RX 6650 XT MECH 2X OC PCI-E 8192Mb GDDR6 128 Bit Retail.jpg"/>

# %% [markdown]
# ##### Задача
# Получение тега с двойным классом
# https://parsinger.ru/4.1/1/index.html

# %%
url = 'https://parsinger.ru/4.1/1/index.html'

# %%
r = requests.get(url)
if r.status_code != 200:
    print(r.status_code, '\n\n', r.text)

# %%
r.encoding = 'utf-8'

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
double_class = soup.find(attrs={'class': 'description detailz'})

# %%
double_class.text
# Out:
# 'Графический процессор: Radeon RX 6650 XT'

# %% [markdown]
# ##### Задача
# Сложный поиск по всем атрибутам и значениям <br> https://parsinger.ru/4.1/1/index2.html

# %%
url = 'https://parsinger.ru/4.1/1/index2.html'

# %%
r = requests.get(url)
if r.status_code != 200:
    print(r.status_code, '\n\n', r.text)

# %%
r.encoding = 'utf-8'

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
tag = soup.find(attrs={'class': 'description_detail class1 class2 class3',
                 'data-fdg45': 'value13',
                 'data-54dfg60': 'value14',
                 'data-d6f50hg': 'value15'
})

# %%
tag.text
# Out:
# 'Объем видеопамяти: 8192Mb'

# %% [markdown]
# ##### Задача 4.4 step 9
# <u>Одновременный поиск и извлечение название товара</u> <br>
# Проанализируйте https://parsinger.ru/4.1/1/index4.html определите тег и его атрибуты, затем примените метод .find_all(), извлеките из каждого соответствующего тега текст и уберите лишние пробелы.

# %%
url = 'https://parsinger.ru/4.1/1/index4.html'

# %%
r = requests.get(url)
if r.status_code != 200:
    print(r.status_code, '\n\n', r.text)

# %%
r.encoding = 'utf-8'

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
list_tags = soup.find_all('a', {'class': 'name_item product_name'})

# %%
for i in list_tags:
    print(i.text.strip())
# Out:
# Видеокарта MSI Radeon RX 6650 XT MECH 2X OC PCI-E 8192Mb GDDR6 128 Bit Retail
# Видеокарта GigaByte nVidia GeForce RTX 3050 WINDFORCE OC 8G PCI-E 8192Mb GDDR6 128 Bit Retail GV-N3050WF2OC-8GD
# Видеокарта Palit nVidia GeForce RTX 4070 GamingPro PCI-E 12288Mb GDDR6X 192 Bit Retail NED4070019K9-1043A
# Видеокарта MSI nVidia GeForce RTX 3060 GAMING X LHR PCI-E 12288Mb GDDR6 192 Bit Retail (RTX 3060 GAMING X 12G)
# Видеокарта MSI nVidia GeForce RTX 4060 Ti GAMING X PCI-E 8192Mb GDDR6 128 Bit Retail
# Видеокарта MSI nVidia GeForce RTX 4060 Ti GAMING X TRIO PCI-E 8192Mb GDDR6 128 Bit Retail
# Видеокарта Palit nVidia GeForce RTX 4060 Dual OC PCI-E 8192Mb GDDR6 128 Bit Retail NE64060T19P1-1070D
# Видеокарта Palit nVidia GeForce RTX 4060 StormX PCI-E 8192Mb GDDR6 128 Bit Retail NE64060019P1-1070F
# Видеокарта Palit nVidia GeForce RTX 4060 DUAL PCI-E 8192Mb GDDR6 128 Bit Retail NE64060019P1-1070D
# Видеокарта MSI nVidia GeForce RTX 4060 Ti GAMING X SLIM 16G PCI-E 16384Mb GDDR6 128 Bit Retail
# ...

# %% [markdown]
# ##### Задача 4.4 step 10
# <u>Суммирование цен на странице</u> <br>
# Проанализируйте структуру сайта (https://parsinger.ru/4.1/1/index4.html), найдите способ получить все цены с помощью .find_all(), затем суммируйте их.

# %%
url = 'https://parsinger.ru/4.1/1/index4.html'

# %%
r = requests.get(url)
if r.status_code != 200:
    print(r.status_code, '\n\n', r.text)

# %%
r.encoding = 'utf-8'

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
prices = [i for i in soup.select('p.[class="price product_price"]')]
# Out:
# ---------------------------------------------------------------------------
# SelectorSyntaxError                       Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 prices = [i for i in soup.select('p.[class="price product_price"]')]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\bs4\element.py:2116, in Tag.select(self, selector, namespaces, limit, **kwargs)
#    2096 def select(self, selector, namespaces=None, limit=None, **kwargs):
#    2097     """Perform a CSS selection operation on the current element.
#    2098
#    2099     This uses the SoupSieve library.
#    (...)
#    2114     :rtype: bs4.element.ResultSet
#    2115     """
# -> 2116     return self.css.select(selector, namespaces, limit, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\bs4\css.py:162, in CSS.select(self, select, namespaces, limit, flags, **kwargs)
#     158 if limit is None:
#     159     limit = 0
#     161 return self._rs(
# ...

# %%
soup.find_all('p', {'class': 'price product_price'})
# Out:
# [<p class="price product_price">29 040 руб</p>,
#  <p class="price product_price">27 840 руб</p>,
#  <p class="price product_price">68 490 руб</p>,
#  <p class="price product_price">41 280 руб</p>,
#  <p class="price product_price">48 720 руб</p>,
#  <p class="price product_price">52 500 руб</p>,
#  <p class="price product_price">35 520 руб</p>,
#  <p class="price product_price">34 720 руб</p>,
#  <p class="price product_price">33 580 руб</p>,
#  <p class="price product_price">55 950 руб</p>,
#  <p class="price product_price">52 260 руб</p>,
#  <p class="price product_price">45 350 руб</p>,
#  <p class="price product_price">89 040 руб</p>,
#  <p class="price product_price">89 620 руб</p>,
#  <p class="price product_price">100 580 руб</p>,
#  <p class="price product_price">68 590 руб</p>,
#  <p class="price product_price">41 350 руб</p>,
#  <p class="price product_price">62 500 руб</p>,
#  <p class="price product_price">44 210 руб</p>,
# ...

# %%
count = 0
for price in prices:
    int_price = int((price.text.rstrip(' руб')).replace(' ', ''))
    count += int_price

# %%
count
# Out:
# 1652100

# %% [markdown]
# ##### Задача 4.4 step 11
# <u>Поиск всех идентификаторов у тегов \<li></u> <br>
# Проанализируйте страницу (https://parsinger.ru/4.1/1/index4.html) и найдите способ извлечь все ID из каждого тега
# \<li>(используйте select() или find_all())

# %%
url = 'https://parsinger.ru/4.1/1/index4.html'

# %%
r = requests.get(url)
if r.status_code != 200:
    print(r.status_code, '\n\n', r.text)

# %%
r.encoding = 'utf-8'

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
soup.select('li[id]')
# Out:
# [<div class="item product_item" id="item_1">
#  <div class="img_box product_img_box">
#  <a href="product/1/1_details.html" name="1_img">
#  <img alt="Видеокарта MSI Radeon RX 6650 XT MECH 2X OC PCI-E 8192Mb GDDR6 128 Bit Retail" src="images/Видеокарта MSI Radeon RX 6650 XT MECH 2X OC PCI-E 8192Mb GDDR6 128 Bit Retail.jpg"/>
#  </a>
#  <a class="name_item product_name" href="product/1/1_details.html" name="1_name">
#                 Видеокарта MSI Radeon RX 6650 XT MECH 2X OC PCI-E 8192Mb GDDR6 128 Bit Retail
#                 </a>
#  <div class="description product_description">
#  <li class="description_detail" data-key="brand" id="item_1_brand">Бренд: MSI</li>
#  <li class="description_detail" data-key="card_type" id="item_1_card_type">Тип видеокарты: игровая</li>
#  <li class="description_detail" data-key="processor_series" id="item_1_processor_series">Серия процессора: Radeon RX</li>
# ...

# %%
tags_find_all = soup.find_all('li', id=True)

# %%
for i in tags_find_all:
    print(i.attrs['id'])
# Out:
# item_1_brand
# item_1_card_type
# item_1_processor_series
# item_1_graphic_processor
# item_1_memory_size
# item_1_memory_type
# item_1_memory_bus
# item_1_connection_type
# item_1_interface
# item_1_hdmi_port
# item_1_displayport
# item_1_power_pins
# item_2_brand
# item_2_card_type
# item_2_processor_series
# item_2_graphic_processor
# item_2_memory_size
# item_2_memory_type
# item_2_memory_bus
# item_2_connection_type
# item_2_interface
# item_2_hdmi_port
# item_2_Разъём DVI
# item_2_displayport
# item_2_power_pins
# item_3_brand
# item_3_card_type
# item_3_processor_series
# item_3_graphic_processor
# item_3_memory_size
# item_3_memory_type
# item_3_memory_bus
# item_3_connection_type
# item_3_interface
# item_3_hdmi_port
# item_3_displayport
# item_3_power_pins
# item_4_brand
# item_4_card_type
# item_4_processor_series
# item_4_graphic_processor
# item_4_memory_size
# item_4_memory_type
# item_4_memory_bus
# item_4_connection_type
# item_4_interface
# item_4_hdmi_port
# ...

# %% [markdown]
# ##### Задача 4.4 step 15
# <u>.previous_sibling и .next_sibling</u><br>
# Проанализируйте HTML на странице (https://parsinger.ru/4.1/1/index6.html) и извлеките из него текст находящийся после
#  третьего раздела. <br>
# Используйте функцию strip() для удаления лишних пробелов.

# %%
url = 'https://parsinger.ru/4.1/1/index6.html'

# %%
r = requests.get(url)
if r.status_code != 200:
    print(r.status_code, '\n\n', r.text)

# %%
r.encoding = 'utf-8'

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
for i in soup.select('p[class]'):
    if i.text == 'Текст раздела 3':
        print(i.next_sibling.strip())
# Out:
# Дополнительный текст рядом с разделом 3.

# %% [markdown]
# ##### Задача 4.4 step 16
# <u>Извлечение всех email со страницы</u><br>
# <li>Проанализируйте предоставленный HTML-код страницы. Ваша задача - обнаружить и извлечь все email-адреса, которые
# находятся вне стандартных тегов. </li>
# <li>Вам предстоит модифицировать функцию ниже таким образом, чтобы она возвращала список всех найденных
# email-адресов, очищенных от лишних пробелов с помощью метода strip().</li>
# <li>Ваша функция должна возвращать список email-адресов в чистом виде, готовых к дальнейшему использованию.</li>
# <p>Пример:</p>
# <ul>['keep2036@duck.com', 'andrea1837@example.org', и т.д.,]</ul>

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://parsinger.ru/4.1/1/index5.html'

# %%
r = requests.get(url)
if r.status_code != 200:
    print(r.status_code, '\n\n', r.text)

# %%
r.encoding = 'utf-8'

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
soup.select('div[class="email_field"] > strong')[0].next_sibling.text.strip()
# Out:
# 'keep2036@duck.com'

# %%
email_list = [i.next_sibling.text.strip() for i in soup.select('div[class="email_field"] > strong')]

# %%
email_list
# Out:
# ['keep2036@duck.com',
#  'andrea1837@example.org',
#  'libs1815@live.com',
#  'travels1859@example.com',
#  'extended1928@protonmail.com',
#  'correctly1802@gmail.com',
#  'strict2037@outlook.com',
#  'allen1886@outlook.com',
#  'weekends1961@example.com',
#  'sorted2073@yandex.com']
